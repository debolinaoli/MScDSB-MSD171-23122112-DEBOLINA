# %%
import random

# Creating lists of items, quantities, and prices
items = ["FERTILISERS", "BANANA", "ALMOND", "EGGS", "APPLES", "MILK", "ONION", "MANGO", "OILSEEDS", "LEMONS"]
quantities = [random.randint(1, 10) for _ in range(10)]
prices = [round(random.uniform(1, 10), 2) for _ in range(10)]

# Create and write to a CSV file
with open('23122112.txt', 'w') as txtfile:
    txtfile.write("Item,Quantity,UnitPrice,TotalCost\n")

    for _ in range(100):
        random_item_index = random.randint(0, 9)
        item = items[random_item_index]
        quantity = quantities[random_item_index]
        price_per_unit = prices[random_item_index]
        total_cost = round(quantity * price_per_unit, 2)
        txtfile.write(f"{item},{quantity},{price_per_unit},{total_cost}\n")

# Read the text file and print results
with open('23122112.txt', 'r') as txtfile:
    next(txtfile)  # skip the header row

    rows = [line.strip().split(',') for line in txtfile]

    print("Results for the first 5 rows:")
    for row in rows[:5]:
        item, quantity, total_cost = row[0], row[1], row[3]
        print(f"Item: {item}, Quantity: {quantity}, Total Cost: {total_cost}")

    print("\nResults for the last 10 rows:")
    for row in rows[-10:]:
        item, quantity, total_cost = row[0], row[1], row[3]
        print(f"Item: {item}, Quantity: {quantity}, Total Cost: {total_cost}")

    # Calculate and print total cost for each unique item
    item_totals = {}
    for row in rows:
        item, quantity, total_cost = row[0], int(row[1]), float(row[3])
        if item in item_totals:
            item_totals[item][0] += quantity
            item_totals[item][1] += total_cost
        else:
            item_totals[item] = [quantity, total_cost]

    print("\nTotal cost for each unique item:")
    for item, (total_quantity, total_cost) in item_totals.items():
        print(f"Item Name: {item}, Total Quantity: {total_quantity}, Total Cost: {total_cost}")

    # Calculate and print min and max prices for each item sold
    item_prices = {}
    for row in rows:
        item, price_per_unit = row[0], float(row[2])
        if item in item_prices:
            item_prices[item].append(price_per_unit)
        else:
            item_prices[item] = [price_per_unit]

    print("\nMinimum and Maximum Prices for Each Item Sold:")
    for item, price_list in item_prices.items():
        min_price = min(price_list)
        max_price = max(price_list)
        print(f"Item: {item}, Min Price: {min_price}, Max Price: {max_price}")
# Out:
# Results for the first 5 rows:
# Item: ONION, Quantity: 6, Total Cost: 26.7
# Item: ALMOND, Quantity: 10, Total Cost: 86.8
# Item: LEMONS, Quantity: 5, Total Cost: 6.5
# Item: BANANA, Quantity: 1, Total Cost: 4.69
# Item: FERTILISERS, Quantity: 2, Total Cost: 8.32
#
# Results for the last 10 rows:
# Item: ALMOND, Quantity: 10, Total Cost: 86.8
# Item: OILSEEDS, Quantity: 6, Total Cost: 51.24
# Item: MILK, Quantity: 10, Total Cost: 62.5
# Item: MILK, Quantity: 10, Total Cost: 62.5
# Item: MANGO, Quantity: 10, Total Cost: 53.3
# Item: ALMOND, Quantity: 10, Total Cost: 86.8
# Item: LEMONS, Quantity: 5, Total Cost: 6.5
# Item: LEMONS, Quantity: 5, Total Cost: 6.5
# Item: LEMONS, Quantity: 5, Total Cost: 6.5
# Item: OILSEEDS, Quantity: 6, Total Cost: 51.24
#
# Total cost for each unique item:
# Item Name: ONION, Total Quantity: 42, Total Cost: 186.89999999999998
# Item Name: ALMOND, Total Quantity: 110, Total Cost: 954.7999999999997
# Item Name: LEMONS, Total Quantity: 80, Total Cost: 104.0
# Item Name: BANANA, Total Quantity: 11, Total Cost: 51.589999999999996
# Item Name: FERTILISERS, Total Quantity: 14, Total Cost: 58.24
# Item Name: APPLES, Total Quantity: 100, Total Cost: 448.00000000000006
# Item Name: MILK, Total Quantity: 110, Total Cost: 687.5
# Item Name: OILSEEDS, Total Quantity: 48, Total Cost: 409.92
# Item Name: EGGS, Total Quantity: 90, Total Cost: 314.1
# Item Name: MANGO, Total Quantity: 90, Total Cost: 479.70000000000005
#
# Minimum and Maximum Prices for Each Item Sold:
# Item: ONION, Min Price: 4.45, Max Price: 4.45
# Item: ALMOND, Min Price: 8.68, Max Price: 8.68
# Item: LEMONS, Min Price: 1.3, Max Price: 1.3
# Item: BANANA, Min Price: 4.69, Max Price: 4.69
# Item: FERTILISERS, Min Price: 4.16, Max Price: 4.16
# Item: APPLES, Min Price: 4.48, Max Price: 4.48
# Item: MILK, Min Price: 6.25, Max Price: 6.25
# Item: OILSEEDS, Min Price: 8.54, Max Price: 8.54
# Item: EGGS, Min Price: 3.49, Max Price: 3.49
# Item: MANGO, Min Price: 5.33, Max Price: 5.33

# %%
import csv
with open("sales.csv", "w", newline="") as csvfile:
    fieldnames = ["Item", "Quantity", "Price", "Total Cost"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    
    total_costs = {}  # To store total cost for each unique item
    
    for _ in range(100):
        random_item_index = random.randint(0, 9)
        quantity = quantities[random_item_index]
        price = prices[random_item_index]
        item = items[random_item_index]
        
        # Calculate total cost for the row
        total_cost = round(quantity * price, 2)
        
        # Write row to CSV
        writer.writerow({"Item": item, "Quantity": quantity, "Price": price, "Total Cost": total_cost})
        
        # Update total cost for the unique item
        if item in total_costs:
            total_costs[item] += total_cost
        else:
            total_costs[item] = total_cost

# Display the total cost for the first 5 rows and last 10 rows
with open("sales.csv", newline="") as csvfile:
    reader = csv.DictReader(csvfile)
    print("Total Cost for First 5 Rows:")
    for _ in range(5):
        row = next(reader)
        print(f"{row['Item']}: {row['Total Cost']}")
    
    print("\nTotal Cost for Last 10 Rows:")
    rows = list(reader)[-10:]
    for row in rows:
        print(f"{row['Item']}: {row['Total Cost']}")

# Calculate and display total cost for each unique item
print("\nTotal Cost for Each Unique Item:")
for item, total_cost in total_costs.items():
    print(f"{item}: {total_cost}")

# Calculate and display minimum & maximum price for each item sold
print("\nMinimum and Maximum Price for Each Item Sold:")
item_prices = {item: [] for item in items}
with open("sales.csv", newline="") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        item = row["Item"]
        price = float(row["Price"])
        item_prices[item].append(price)

for item, prices in item_prices.items():
    min_price = min(prices)
    max_price = max(prices)
    print(f"{item}: Min Price: {min_price}, Max Price: {max_price}")
# Out:
# Total Cost for First 5 Rows:
# OILSEEDS: 51.24
# ALMOND: 86.8
# MILK: 62.5
# ALMOND: 86.8
# OILSEEDS: 51.24
#
# Total Cost for Last 10 Rows:
# APPLES: 44.8
# MILK: 62.5
# MILK: 62.5
# FERTILISERS: 8.32
# LEMONS: 6.5
# FERTILISERS: 8.32
# LEMONS: 6.5
# APPLES: 44.8
# MANGO: 53.3
# EGGS: 31.41
#
# Total Cost for Each Unique Item:
# OILSEEDS: 614.88
# ALMOND: 694.3999999999999
# MILK: 812.5
# FERTILISERS: 83.19999999999999
# LEMONS: 65.0
# EGGS: 251.28
# BANANA: 56.279999999999994
# ONION: 293.69999999999993
# MANGO: 533.0
# APPLES: 268.8
#
# Minimum and Maximum Price for Each Item Sold:
# FERTILISERS: Min Price: 4.16, Max Price: 4.16
# BANANA: Min Price: 4.69, Max Price: 4.69
# ALMOND: Min Price: 8.68, Max Price: 8.68
# EGGS: Min Price: 3.49, Max Price: 3.49
# APPLES: Min Price: 4.48, Max Price: 4.48
# MILK: Min Price: 6.25, Max Price: 6.25
# ONION: Min Price: 4.45, Max Price: 4.45
# MANGO: Min Price: 5.33, Max Price: 5.33
# OILSEEDS: Min Price: 8.54, Max Price: 8.54
# LEMONS: Min Price: 1.3, Max Price: 1.3
