# %% [markdown]
# IMPORTING PYTHON LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# RREADING THE DATASET

# %%
cac=pd.read_csv("d:\MScDSB-MSD171-23122112-DEBOLINA\python cac2.csv")
cac
# Out:
#                Timestamp Select Your Branch.  \
# 0       08-10-2023 17:16        Data Science
# 1       08-10-2023 17:17        Data Science
# 2       08-10-2023 17:18        Data Science
# 3       08-10-2023 17:28              BA LLB
# 4       08-10-2023 17:30              BA LLB
# ..                   ...                 ...
# 297  10/20/2023 18:54:01                 MBA
# 298  10/20/2023 18:54:22        Data Science
# 299  10/20/2023 18:54:43                 MBA
# 300  10/20/2023 18:55:04                 MBA
# 301  10/21/2023 15:10:59        Data Science
#
#      How much money you get for monthly expenses from family?  \
# 0                                                 8000
# 1                                                 5000
# 2                                                10000
# 3                                                10000
# 4                                                10000
# ..                                                 ...
# 297                                              10000
# 298                                               9000
# 299                                               8000
# 300                                              10000
# 301                                               5000
#
#      How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  \
# 0                                                 7000
# 1                                                 3000
# 2                                                 5000
# 3                                                 3000
# 4                                                 7000
# ..                                                 ...
# 297                                               8000
# 298                                               8000
# 299                                               7000
# 300                                               7000
# 301                                               3000
#
#      Have you spend on any medical requirements?  \
# 0                                           1000
# 1                                           1000
# 2                                              0
# 3                                              0
# 4                                              0
# ..                                           ...
# 297                                         2000
# 298                                         2000
# 299                                            0
# 300                                         1000
# 301                                            0
#
#     Have you asked your parents for money due to poor money management skills?  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 297                                                 No
# 298                                                 No
# 299                                                 No
# 300                                                 No
# 301                                                 No
#
#      Have you paid fine in Christ?  Are you able to save money?
# 0                              0.0                         1000
# 1                              0.0                          500
# 2                              0.0                            0
# 3                              0.0                         1500
# 4                              0.0                         2000
# ..                             ...                          ...
# 297                            0.0                          400
# 298                            0.0                         1500
# 299                            0.0                         1000
# 300                            0.0                         1000
# 301                            0.0                          400
#
# [302 rows x 8 columns]

# %% [markdown]
# ANALYZING THE DATA :
# Here we want to check how many rows and columns the dataset have, information regarding each column,how many missing values are there and their data types.

# %%
# To show the top 5 observations of the dataset
cac.head()
# Out:
#           Timestamp Select Your Branch.  \
# 0  08-10-2023 17:16        Data Science
# 1  08-10-2023 17:17        Data Science
# 2  08-10-2023 17:18        Data Science
# 3  08-10-2023 17:28              BA LLB
# 4  08-10-2023 17:30              BA LLB
#
#    How much money you get for monthly expenses from family?  \
# 0                                               8000
# 1                                               5000
# 2                                              10000
# 3                                              10000
# 4                                              10000
#
#    How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  \
# 0                                               7000
# 1                                               3000
# 2                                               5000
# 3                                               3000
# 4                                               7000
#
#    Have you spend on any medical requirements?  \
# 0                                         1000
# 1                                         1000
# 2                                            0
# 3                                            0
# 4                                            0
#
#   Have you asked your parents for money due to poor money management skills?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#    Have you paid fine in Christ?  Are you able to save money?
# 0                            0.0                         1000
# 1                            0.0                          500
# 2                            0.0                            0
# 3                            0.0                         1500
# 4                            0.0                         2000

# %%
#To show the bottom 5 obseravtions of the dataset
cac.tail()
# Out:
#                Timestamp Select Your Branch.  \
# 297  10/20/2023 18:54:01                 MBA
# 298  10/20/2023 18:54:22        Data Science
# 299  10/20/2023 18:54:43                 MBA
# 300  10/20/2023 18:55:04                 MBA
# 301  10/21/2023 15:10:59        Data Science
#
#      How much money you get for monthly expenses from family?  \
# 297                                              10000
# 298                                               9000
# 299                                               8000
# 300                                              10000
# 301                                               5000
#
#      How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  \
# 297                                               8000
# 298                                               8000
# 299                                               7000
# 300                                               7000
# 301                                               3000
#
#      Have you spend on any medical requirements?  \
# 297                                         2000
# 298                                         2000
# 299                                            0
# 300                                         1000
# 301                                            0
#
#     Have you asked your parents for money due to poor money management skills?  \
# 297                                                 No
# 298                                                 No
# 299                                                 No
# 300                                                 No
# 301                                                 No
#
#      Have you paid fine in Christ?  Are you able to save money?
# 297                            0.0                          400
# 298                            0.0                         1500
# 299                            0.0                         1000
# 300                            0.0                         1000
# 301                            0.0                          400

# %%
# To get the information about each column of the dataset
cac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 8 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Timestamp                                                                            302 non-null    object
#  1   Select Your Branch.                                                                  302 non-null    object
#  2   How much money you get for monthly expenses from family?                             302 non-null    int64
#  3   How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  302 non-null    int64
#  4   Have you spend on any medical requirements?                                          302 non-null    int64
#  5   Have you asked your parents for money due to poor money management skills?           302 non-null    object
#  6   Have you paid fine in Christ?                                                        301 non-null    float64
#  7   Are you able to save money?                                                          302 non-null    int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 19.0+ KB

# %%
cac.rename(columns={
        'Have you asked your parents for money due to poor money management skills': 'extra money', 
        'Have you paid fine in Christ \n': 'pay fine'
        }, inplace=True)

cac.columns
# Out:
# Index(['Timestamp', 'Select Your Branch.',
#        'How much money you get for monthly expenses from family?',
#        'How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)',
#        'Have you spend on any medical requirements?',
#        'Have you asked your parents for money due to poor money management skills?',
#        'Have you paid fine in Christ?', 'Are you able to save money?'],
#       dtype='object')

# %%
cac.shape
# Out:
# (302, 8)

# %% [markdown]
# DATA CLEANING :
#
# We have to clean the data for further analysis. The following are the ways we can clean our data to proceed further:
# 1) Removing unwanted columns.
# 2) Replacing or emoving the missing values according to requirement
# 3) Removing duplicates from the data

# %%
#Checking for the no.of missing Values each column has.
cac.isnull().sum()
# Out:
# Timestamp                                                                              0
# Select Your Branch.                                                                    0
# How much money you get for monthly expenses from family?                               0
# How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)    0
# Have you spend on any medical requirements?                                            0
# Have you asked your parents for money due to poor money management skills?             0
# Have you paid fine in Christ?                                                          1
# Are you able to save money?                                                            0
# dtype: int64

# %%
# percentage of missing values each has 
(cac.isnull().sum()/(len(cac)))*100
# Out:
# Timestamp                                                                              0.000000
# Select Your Branch.                                                                    0.000000
# How much money you get for monthly expenses from family?                               0.000000
# How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)    0.000000
# Have you spend on any medical requirements?                                            0.000000
# Have you asked your parents for money due to poor money management skills?             0.000000
# Have you paid fine in Christ?                                                          0.331126
# Are you able to save money?                                                            0.000000
# dtype: float64

# %%
# to check the datatypes of each column
cac.dtypes
# Out:
# Timestamp                                                                               object
# Select Your Branch.                                                                     object
# How much money you get for monthly expenses from family?                                 int64
# How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)      int64
# Have you spend on any medical requirements?                                              int64
# Have you asked your parents for money due to poor money management skills?              object
# Have you paid fine in Christ?                                                          float64
# Are you able to save money?                                                              int64
# dtype: object

# %%
# We are removing the columns that are not required in the dataset
cac = cac.drop(['Timestamp'], axis = 1)

cac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 7 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Select Your Branch.                                                                  302 non-null    object
#  1   How much money you get for monthly expenses from family?                             302 non-null    int64
#  2   How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  302 non-null    int64
#  3   Have you spend on any medical requirements?                                          302 non-null    int64
#  4   Have you asked your parents for money due to poor money management skills?           302 non-null    object
#  5   Have you paid fine in Christ?                                                        301 non-null    float64
#  6   Are you able to save money?                                                          302 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 16.6+ KB

# %%
df=cac.drop_duplicates(keep='last')
df
# Out:
#     Select Your Branch.  \
# 0          Data Science
# 1          Data Science
# 2          Data Science
# 3                BA LLB
# 4                BA LLB
# ..                  ...
# 297                 MBA
# 298        Data Science
# 299                 MBA
# 300                 MBA
# 301        Data Science
#
#      How much money you get for monthly expenses from family?  \
# 0                                                 8000
# 1                                                 5000
# 2                                                10000
# 3                                                10000
# 4                                                10000
# ..                                                 ...
# 297                                              10000
# 298                                               9000
# 299                                               8000
# 300                                              10000
# 301                                               5000
#
#      How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  \
# 0                                                 7000
# 1                                                 3000
# 2                                                 5000
# 3                                                 3000
# 4                                                 7000
# ..                                                 ...
# 297                                               8000
# 298                                               8000
# 299                                               7000
# 300                                               7000
# 301                                               3000
#
#      Have you spend on any medical requirements?  \
# 0                                           1000
# 1                                           1000
# 2                                              0
# 3                                              0
# 4                                              0
# ..                                           ...
# 297                                         2000
# 298                                         2000
# 299                                            0
# 300                                         1000
# 301                                            0
#
#     Have you asked your parents for money due to poor money management skills?  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 297                                                 No
# 298                                                 No
# 299                                                 No
# 300                                                 No
# 301                                                 No
#
#      Have you paid fine in Christ?  Are you able to save money?
# 0                              0.0                         1000
# 1                              0.0                          500
# 2                              0.0                            0
# 3                              0.0                         1500
# 4                              0.0                         2000
# ..                             ...                          ...
# 297                            0.0                          400
# 298                            0.0                         1500
# 299                            0.0                         1000
# 300                            0.0                         1000
# 301                            0.0                          400
#
# [290 rows x 7 columns]

# %%
cac.describe()
# Out:
#        How much money you get for monthly expenses from family?  \
# count                                         302.000000
# mean                                         8062.913907
# std                                          1761.346355
# min                                          5000.000000
# 25%                                          6000.000000
# 50%                                          8000.000000
# 75%                                         10000.000000
# max                                         10000.000000
#
#        How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)  \
# count                                         302.000000
# mean                                         5503.311258
# std                                          1605.117117
# min                                          3000.000000
# 25%                                          4000.000000
# 50%                                          6000.000000
# 75%                                          7000.000000
# max                                          8000.000000
#
#        Have you spend on any medical requirements?  \
# count                                   302.000000
# mean                                   1086.092715
# std                                    1275.584147
# min                                       0.000000
# 25%                                       0.000000
# 50%                                    1000.000000
# 75%                                    1000.000000
# max                                    6000.000000
#
#        Have you paid fine in Christ?  Are you able to save money?
# count                     301.000000                   302.000000
# mean                      415.282392                   710.596026
# std                       974.832808                   656.544090
# min                         0.000000                     0.000000
# 25%                         0.000000                     0.000000
# 50%                         0.000000                   500.000000
# 75%                         0.000000                  1000.000000
# max                      6000.000000                  2000.000000

# %% [markdown]
# EDA UNIVARIATE ANALYSIS
#
# We are trying to analyze each factor and since they are categorical we are trying to focus on their frequency of occurence.
# We shall also compare two factors and try to visualize by the following plots.

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="How much money you get for monthly expenses from family?", 
                kind="count", height=5,aspect=1.25,
                data=cac,color="brown")

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="Have you paid fine in Christ?", 
                kind="count", 
                data=cac,color="red")

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="How much do you spend on your Food? (includes Breakfast, Lunch, Dinner, Tea/Coffee)", 
                kind="count", 
                data=cac,color="deeppink",aspect=1.5)

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(y="Have you spend on any medical requirements?", 
                kind="count", 
                data=cac,color="green")
